# %%
import pandas as pd
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %% [markdown]
# ## Organize training data

# %%
Train_file_PAT =r'.//train_dataset//PAT_dataset_XY.tsv'
# read tsv
train_ds = pd.read_csv(Train_file_PAT, sep='\t', na_values=['.'], header=0)
train_ds = train_ds.drop(train_ds.columns[range(4)],axis=1)
train_ds = train_ds.fillna(train_ds.mean())

# pandas.DataFrame -->numpy
train_np = train_ds.values
x_train = train_np[:, :-1]
y_train = train_np[:, -1]

# %% [markdown]
# ## Organize testing data

# %%
test_dataset_filename = ['Rare_Patho_SNV'] 
x_test = {}
y_test = {}
    
for test_index, test_file_name in enumerate(test_dataset_filename,start=0):
    test_file =  r'.//test_dataset//' + test_file_name +'_dataset_XY.tsv'    
    test_ds = pd.read_csv(test_file, sep='\t', na_values=['.'], header=0)
    
    if(test_ds.shape[1] == 19):
        test_ds = test_ds.fillna(train_ds.mean())
        test_ds = test_ds.drop(test_ds.columns[range(4)], axis=1)
    elif(test_ds.shape[1] == 30):
        test_ds = test_ds.fillna(train_ds.mean())
        test_ds = test_ds.drop(test_ds.columns[range(4)], axis=1)

    test_np = test_ds.values
    x_test[test_index] = test_np[:, :-1]
    y_test[test_index] = test_np[:, -1]

# %% [markdown]
# ## Model building

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier,GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingClassifier as GBDT
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.ensemble import StackingClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression as LR
from sklearn.svm import LinearSVC,SVC
from sklearn.model_selection import StratifiedKFold,GridSearchCV

# %% [markdown]
# ### Building Stacking

# %%
from sklearn import metrics
PAT = {"colsample_bylevel":0.3,"colsample_bytree":1.0,"gamma":3.6,"learning_rate":0.1,"max_depth":3,
 "min_child_weight":8.0,"n_estimators":100,"reg_alpha":0.001,"reg_lambda":2.0, "scale_pos_weight":12.1599539701,"subsample":0.7}

estimators = [     
        ('GBDT',GBDT(criterion='friedman_mse', learning_rate=0.20, loss='exponential', min_samples_split=22, n_estimators=70)),
        ('KNN',KNN(n_neighbors=95,p=1,weights='distance')),
        ('LR',LR(C=20,penalty='l2', solver='lbfgs',max_iter=300)),
        ('regBase', XGBClassifier( **PAT)),
        ('RF', RandomForestClassifier(class_weight='balanced', criterion = 'entropy', max_depth=10, min_samples_split=82, n_estimators=68)),
        ('SVM', SVC(C=21,gamma=0.05,probability=True))
]
stacking_EXT = ExtraTreesClassifier(criterion='gini',max_depth=80,min_samples_leaf=4,min_samples_split=17,n_estimators=150)
PAT_Stacking = StackingClassifier(estimators=estimators, final_estimator = stacking_EXT,stack_method='predict_proba',n_jobs=12,passthrough=True)

# %% [markdown]
# ### Building Basemodels

# %%
from sklearn.model_selection import StratifiedKFold

PAT = {"colsample_bylevel":0.3,"colsample_bytree":1.0,"gamma":3.6,"learning_rate":0.1,"max_depth":3,
 "min_child_weight":8.0,"n_estimators":100,"reg_alpha":0.001,"reg_lambda":2.0, "scale_pos_weight":12.1599539701,"subsample":0.7}

skfFoldtime = 5
skf = StratifiedKFold(n_splits= skfFoldtime,shuffle=True,random_state=10)

PAT_GBDT = GBDT(criterion='friedman_mse', learning_rate=0.07, loss='exponential', min_samples_split=22, n_estimators=15)
PAT_KNN = KNN(n_neighbors=95,p=1,weights='distance')
PAT_LR = LR(C=20,penalty='l2', solver='lbfgs',max_iter=300)
PAT_XGBoost = XGBClassifier( **PAT)
PAT_RF = RandomForestClassifier( criterion = 'entropy', max_depth=3, min_samples_split=82, n_estimators=32)
PAT_SVM = SVC(C=21,gamma=0.05,probability=True)

# %%
PAT_model_List = [PAT_GBDT, PAT_KNN, PAT_LR, PAT_XGBoost, PAT_RF, PAT_SVM, PAT_Stacking]

# %% [markdown]
# ### All models fitting

# %%
## Get the instance name
import inspect
def retrieve_name(var):
    '''
    utils:
    get back the name of variables
    '''
    callers_local_vars = inspect.currentframe().f_back.f_locals.items()
    return [var_name for var_name, var_val in callers_local_vars if var_val is var]

# %%
for index_classifier, (classifier) in enumerate(PAT_model_List,start=0):
    print(retrieve_name(classifier)[0],'is fitting =======================')
    classifier.fit(x_train, y_train)
# Out:
# PAT_GBDT is fitting =======================
# PAT_KNN is fitting =======================
# PAT_LR is fitting =======================
# PAT_XGBoost is fitting =======================
# PAT_RF is fitting =======================
# PAT_SVM is fitting =======================
# PAT_Stacking is fitting =======================

# %% [markdown]
# ### model_save

# %%
import joblib
for fitted_classifier in PAT_model_List:
    filename = ".//model//PAT//" + retrieve_name(fitted_classifier)[0] + ".model"
    joblib.dump(fitted_classifier, filename = filename)

# %%
from sklearn.metrics import roc_curve,roc_auc_score,auc

def multi_models_roc(names, sampling_methods, colors, X_test, y_test, save_name, save=True, dpin=100):
        """
        Output the AUROC results obtained by all models to a graph
        
        Args:
            names: list, model names
            sampling_methods: list, instantiated objects for all models
            save: Choose whether to save the result (default is png format)
            
        Returns:
            Returns the image object plt
        """
        plt.figure(figsize=(5, 5), dpi=dpin)

        for (name, method, colorname) in zip(names, sampling_methods, colors):
            y_test_preds = method.predict(X_test)
            y_test_predprob = method.predict_proba(X_test)[:,1]
            fpr, tpr, thresholds = roc_curve(y_test, y_test_predprob, pos_label=1)
            
            plt.plot(fpr, tpr, lw=2, label='{} (AUC={:.4f})'.format(name, auc(fpr, tpr)),color = colorname)
            plt.plot([0, 1], [0, 1], '--', lw=2, color = 'grey')
            plt.axis('square')  
            plt.xlim([0, 1])
            plt.ylim([0, 1])
            plt.xlabel('False Positive Rate',fontsize=13)
            plt.ylabel('True Positive Rate',fontsize=13)
            plt.title('Rare_Patho_SNV',fontsize=20)
            plt.legend(loc='lower right',fontsize=11)

        if save:
            plt.savefig('PAT_auroc'+save_name+'_baseClf.png')
            
        return plt

# %%
from sklearn.metrics import roc_curve,roc_auc_score,auc

def multi_models_auprc(names, sampling_methods, colors, X_test, y_test,  save_name, save=True, dpin=100):
        """
        Output the Auprc results obtained by all models to a graph
        
        Args:
            names: list, model names
            sampling_methods: list, instantiated objects for all models
            save: Choose whether to save the result (default is png format)
            
        Returns:
            Returns the image object plt
        """
            
            
        plt.figure(figsize=(5, 5), dpi=dpin)

        for (name, method, colorname) in zip(names, sampling_methods, colors):
            y_test_predprob = method.predict_proba(X_test)[:,1]
            fpr, tpr, thresholds = roc_curve(y_test, y_test_predprob, pos_label=1)
            precision, recall,_ = precision_recall_curve(y_test, y_test_predprob)
            
            plt.plot(recall, precision, lw=2, label='{} (AUC={:.4f})'.format(name, auc(recall, precision)),color = colorname)
            plt.plot([0, 1], [0, 1], '--', lw=2, color = 'grey')
            plt.axis('square')  
            plt.xlim([0, 1])
            plt.ylim([0, 1])
            plt.xlabel('Recall',fontsize=13)
            plt.ylabel('Precision',fontsize=13)
            plt.title('Rare_Patho_SNV',fontsize=20)
            plt.legend(loc='lower right',fontsize=11)

        if save:
            plt.savefig('PAT_multi_models_aupr'+save_name+'_baseClf.png')
            
        return plt

# %% [markdown]
# #### get predictions

# %%
from sklearn import metrics
from sklearn.metrics import precision_recall_curve
names = ['GBDT', 'KNN', 'LR', 'XGBoost', 'RF','SVM' ,'Stacking']

colors = ['crimson',
          'orange',
          'gold',
          'mediumseagreen',
          'steelblue', 
          'mediumpurple',
          'green',
          'black'
]

PAT_ROC_graph = multi_models_roc(names, PAT_model_List, colors,x_test[0],y_test[0],save_name="brown")
PAT_AUPRC_graph = multi_models_auprc(names, PAT_model_List, colors,x_test[0],y_test[0],save_name="brown")

# %% [markdown]
# ## Other_methods

# %% [markdown]
# ### CADD,CScape,DANN,FATHMM-MKL,FIRE

# %%
colors = ['crimson',
          'orange',
          'gold',
          'mediumseagreen',
          'steelblue',
]

method_list = ['CADD','CScape','DANN','FATHMM-MKL','FIRE']
method_data = {}
method_data[0] = np.concatenate((test_ds['CADD'].values.reshape(-1,1), test_ds['CScape'].values.reshape(-1,1),
                            test_ds['DANN'].values.reshape(-1,1),test_ds['FATHMM-MKL'].values.reshape(-1,1),
                            test_ds['FIRE'].values.reshape(-1,1)),axis=1)


print(method_data[0].shape)
# Out:
# (102, 5)

# %% [markdown]
# ### DeppGS

# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt 
from tensorflow.keras.layers import Input, Dense, Conv1D, Dropout, MaxPooling1D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers
from tensorflow.keras.utils import to_categorical

# model_build
inp = Input(shape=(14,1))
x = Conv1D(14,10,activation='relu')(inp)
x = MaxPooling1D(pool_size=4,strides=4)(x)
x = Dropout(0.2)(x)
x = Flatten()(x)
x = Dense(32, activation='relu')(x)
x = Dropout(0.1)(x)
x = Dense(2, activation='sigmoid')(x)
out = Dropout(0.05)(x)

model_DeepGS = Model(inputs=inp, outputs=out)
sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.5, nesterov=False)
model_DeepGS.compile(optimizer='sgd',
              loss='mean_absolute_error',
              metrics=['mae'])

# model.fit
y_one_hot = to_categorical(y_train, num_classes=None)
model_DeepGS.fit(x_train.reshape((-1,14,1)), y_one_hot, batch_size=256, 
              validation_split=0.1,epochs=100 )

y_test_predprob_DeepGS = {}
method_list.append('DeepGS')
for test_index, test_file_name in enumerate(test_dataset_filename,start=0):
    print(test_index)
    y_test_predprob_DeepGS[test_index] = model_DeepGS.predict(x_test[test_index])[:,1]
    print(y_test_predprob_DeepGS[test_index].shape)
    method_data[test_index] = np.append(method_data[test_index],y_test_predprob_DeepGS[test_index].reshape(-1,1),axis = 1)
# Out:
# Epoch 1/100
# 41/41 [==============================] - 1s 8ms/step - loss: 0.5214 - mae: 0.5214 - val_loss: 0.4860 - val_mae: 0.4860
# Epoch 2/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.4796 - mae: 0.4796 - val_loss: 0.4862 - val_mae: 0.4862
# Epoch 3/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.4412 - mae: 0.4412 - val_loss: 0.4865 - val_mae: 0.4865
# Epoch 4/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.4034 - mae: 0.4034 - val_loss: 0.4853 - val_mae: 0.4853
# Epoch 5/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.3640 - mae: 0.3640 - val_loss: 0.4818 - val_mae: 0.4818
# Epoch 6/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.3201 - mae: 0.3201 - val_loss: 0.4756 - val_mae: 0.4756
# Epoch 7/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.2799 - mae: 0.2799 - val_loss: 0.4668 - val_mae: 0.4668
# Epoch 8/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.2397 - mae: 0.2397 - val_loss: 0.4564 - val_mae: 0.4564
# Epoch 9/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.2081 - mae: 0.2081 - val_loss: 0.4458 - val_mae: 0.4458
# Epoch 10/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.1814 - mae: 0.1814 - val_loss: 0.4363 - val_mae: 0.4363
# Epoch 11/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.1571 - mae: 0.1571 - val_loss: 0.4284 - val_mae: 0.4284
# Epoch 12/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.1411 - mae: 0.1411 - val_loss: 0.4222 - val_mae: 0.4222
# Epoch 13/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.1304 - mae: 0.1304 - val_loss: 0.4172 - val_mae: 0.4172
# Epoch 14/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.1211 - mae: 0.1211 - val_loss: 0.4134 - val_mae: 0.4134
# Epoch 15/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.1167 - mae: 0.1167 - val_loss: 0.4105 - val_mae: 0.4105
# Epoch 16/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.1089 - mae: 0.1089 - val_loss: 0.4081 - val_mae: 0.4081
# Epoch 17/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.1079 - mae: 0.1079 - val_loss: 0.4061 - val_mae: 0.4061
# Epoch 18/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0995 - mae: 0.0995 - val_loss: 0.4045 - val_mae: 0.4045
# Epoch 19/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.1029 - mae: 0.1029 - val_loss: 0.4032 - val_mae: 0.4032
# Epoch 20/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.1015 - mae: 0.1015 - val_loss: 0.4022 - val_mae: 0.4022
# Epoch 21/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0971 - mae: 0.0971 - val_loss: 0.4012 - val_mae: 0.4012
# Epoch 22/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0978 - mae: 0.0978 - val_loss: 0.4004 - val_mae: 0.4004
# Epoch 23/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0946 - mae: 0.0946 - val_loss: 0.3998 - val_mae: 0.3998
# Epoch 24/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0938 - mae: 0.0938 - val_loss: 0.3992 - val_mae: 0.3992
# Epoch 25/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0939 - mae: 0.0939 - val_loss: 0.3987 - val_mae: 0.3987
# Epoch 26/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0909 - mae: 0.0909 - val_loss: 0.3982 - val_mae: 0.3982
# Epoch 27/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0942 - mae: 0.0942 - val_loss: 0.3978 - val_mae: 0.3978
# Epoch 28/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0957 - mae: 0.0957 - val_loss: 0.3975 - val_mae: 0.3975
# Epoch 29/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0952 - mae: 0.0952 - val_loss: 0.3972 - val_mae: 0.3972
# Epoch 30/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0924 - mae: 0.0924 - val_loss: 0.3970 - val_mae: 0.3970
# Epoch 31/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0888 - mae: 0.0888 - val_loss: 0.3968 - val_mae: 0.3968
# Epoch 32/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0862 - mae: 0.0862 - val_loss: 0.3966 - val_mae: 0.3966
# Epoch 33/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0862 - mae: 0.0862 - val_loss: 0.3964 - val_mae: 0.3964
# Epoch 34/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0898 - mae: 0.0898 - val_loss: 0.3963 - val_mae: 0.3963
# Epoch 35/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0862 - mae: 0.0862 - val_loss: 0.3961 - val_mae: 0.3961
# Epoch 36/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0871 - mae: 0.0871 - val_loss: 0.3960 - val_mae: 0.3960
# Epoch 37/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0899 - mae: 0.0899 - val_loss: 0.3959 - val_mae: 0.3959
# Epoch 38/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0863 - mae: 0.0863 - val_loss: 0.3958 - val_mae: 0.3958
# Epoch 39/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0834 - mae: 0.0834 - val_loss: 0.3958 - val_mae: 0.3958
# Epoch 40/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0867 - mae: 0.0867 - val_loss: 0.3957 - val_mae: 0.3957
# Epoch 41/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0849 - mae: 0.0849 - val_loss: 0.3956 - val_mae: 0.3956
# Epoch 42/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0866 - mae: 0.0866 - val_loss: 0.3956 - val_mae: 0.3956
# Epoch 43/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0879 - mae: 0.0879 - val_loss: 0.3955 - val_mae: 0.3955
# Epoch 44/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0873 - mae: 0.0873 - val_loss: 0.3955 - val_mae: 0.3955
# Epoch 45/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0838 - mae: 0.0838 - val_loss: 0.3954 - val_mae: 0.3954
# Epoch 46/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0871 - mae: 0.0871 - val_loss: 0.3954 - val_mae: 0.3954
# Epoch 47/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0861 - mae: 0.0861 - val_loss: 0.3954 - val_mae: 0.3954
# Epoch 48/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0819 - mae: 0.0819 - val_loss: 0.3953 - val_mae: 0.3953
# Epoch 49/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0801 - mae: 0.0801 - val_loss: 0.3953 - val_mae: 0.3953
# Epoch 50/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0814 - mae: 0.0814 - val_loss: 0.3953 - val_mae: 0.3953
# Epoch 51/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0841 - mae: 0.0841 - val_loss: 0.3954 - val_mae: 0.3954
# Epoch 52/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0842 - mae: 0.0842 - val_loss: 0.3953 - val_mae: 0.3953
# Epoch 53/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0810 - mae: 0.0810 - val_loss: 0.3953 - val_mae: 0.3953
# Epoch 54/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0835 - mae: 0.0835 - val_loss: 0.3954 - val_mae: 0.3954
# Epoch 55/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0843 - mae: 0.0843 - val_loss: 0.3954 - val_mae: 0.3954
# Epoch 56/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0877 - mae: 0.0877 - val_loss: 0.3954 - val_mae: 0.3954
# Epoch 57/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0808 - mae: 0.0808 - val_loss: 0.3954 - val_mae: 0.3954
# Epoch 58/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0787 - mae: 0.0787 - val_loss: 0.3954 - val_mae: 0.3954
# Epoch 59/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0830 - mae: 0.0830 - val_loss: 0.3954 - val_mae: 0.3954
# Epoch 60/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0835 - mae: 0.0835 - val_loss: 0.3954 - val_mae: 0.3954
# Epoch 61/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0807 - mae: 0.0807 - val_loss: 0.3954 - val_mae: 0.3954
# Epoch 62/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0817 - mae: 0.0817 - val_loss: 0.3954 - val_mae: 0.3954
# Epoch 63/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0869 - mae: 0.0869 - val_loss: 0.3955 - val_mae: 0.3955
# Epoch 64/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0854 - mae: 0.0854 - val_loss: 0.3955 - val_mae: 0.3955
# Epoch 65/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0856 - mae: 0.0856 - val_loss: 0.3955 - val_mae: 0.3955
# Epoch 66/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0851 - mae: 0.0851 - val_loss: 0.3955 - val_mae: 0.3955
# Epoch 67/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0831 - mae: 0.0831 - val_loss: 0.3956 - val_mae: 0.3956
# Epoch 68/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0836 - mae: 0.0836 - val_loss: 0.3956 - val_mae: 0.3956
# Epoch 69/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0841 - mae: 0.0841 - val_loss: 0.3956 - val_mae: 0.3956
# Epoch 70/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0824 - mae: 0.0824 - val_loss: 0.3956 - val_mae: 0.3956
# Epoch 71/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0803 - mae: 0.0803 - val_loss: 0.3957 - val_mae: 0.3957
# Epoch 72/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0822 - mae: 0.0822 - val_loss: 0.3957 - val_mae: 0.3957
# Epoch 73/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0797 - mae: 0.0797 - val_loss: 0.3957 - val_mae: 0.3957
# Epoch 74/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0826 - mae: 0.0826 - val_loss: 0.3957 - val_mae: 0.3957
# Epoch 75/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0839 - mae: 0.0839 - val_loss: 0.3958 - val_mae: 0.3958
# Epoch 76/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0821 - mae: 0.0821 - val_loss: 0.3958 - val_mae: 0.3958
# Epoch 77/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0838 - mae: 0.0838 - val_loss: 0.3958 - val_mae: 0.3958
# Epoch 78/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0810 - mae: 0.0810 - val_loss: 0.3959 - val_mae: 0.3959
# Epoch 79/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0841 - mae: 0.0841 - val_loss: 0.3959 - val_mae: 0.3959
# Epoch 80/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0810 - mae: 0.0810 - val_loss: 0.3960 - val_mae: 0.3960
# Epoch 81/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0821 - mae: 0.0821 - val_loss: 0.3960 - val_mae: 0.3960
# Epoch 82/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0819 - mae: 0.0819 - val_loss: 0.3960 - val_mae: 0.3960
# Epoch 83/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0819 - mae: 0.0819 - val_loss: 0.3961 - val_mae: 0.3961
# Epoch 84/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0822 - mae: 0.0822 - val_loss: 0.3961 - val_mae: 0.3961
# Epoch 85/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0828 - mae: 0.0828 - val_loss: 0.3961 - val_mae: 0.3961
# Epoch 86/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0812 - mae: 0.0812 - val_loss: 0.3962 - val_mae: 0.3962
# Epoch 87/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0771 - mae: 0.0771 - val_loss: 0.3962 - val_mae: 0.3962
# Epoch 88/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0828 - mae: 0.0828 - val_loss: 0.3963 - val_mae: 0.3963
# Epoch 89/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0839 - mae: 0.0839 - val_loss: 0.3963 - val_mae: 0.3963
# Epoch 90/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0833 - mae: 0.0833 - val_loss: 0.3963 - val_mae: 0.3963
# Epoch 91/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0842 - mae: 0.0842 - val_loss: 0.3963 - val_mae: 0.3963
# Epoch 92/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0838 - mae: 0.0838 - val_loss: 0.3963 - val_mae: 0.3963
# Epoch 93/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0816 - mae: 0.0816 - val_loss: 0.3963 - val_mae: 0.3963
# Epoch 94/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0777 - mae: 0.0777 - val_loss: 0.3964 - val_mae: 0.3964
# Epoch 95/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0833 - mae: 0.0833 - val_loss: 0.3964 - val_mae: 0.3964
# Epoch 96/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0803 - mae: 0.0803 - val_loss: 0.3965 - val_mae: 0.3965
# Epoch 97/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0745 - mae: 0.0745 - val_loss: 0.3965 - val_mae: 0.3965
# Epoch 98/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0798 - mae: 0.0798 - val_loss: 0.3965 - val_mae: 0.3965
# Epoch 99/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0778 - mae: 0.0778 - val_loss: 0.3965 - val_mae: 0.3965
# Epoch 100/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0804 - mae: 0.0804 - val_loss: 0.3966 - val_mae: 0.3966
# 0
# (102,)

# %% [markdown]
# ### regBase

# %%
from xgboost import XGBClassifier
PAT = {"colsample_bylevel":0.3,"colsample_bytree":1.0,"gamma":3.6,"learning_rate":0.1,"max_depth":3,
 "min_child_weight":8.0,"n_estimators":100,"reg_alpha":0.001,"reg_lambda":2.0, "scale_pos_weight":12.1599539701,"subsample":0.7}


model_regBase = XGBClassifier(n_jobs=2, **PAT)

model_regBase.fit(x_train, y_train)

y_test_predprob_regBase = {}
method_list.append('regBase')
for test_index, test_file_name in enumerate(test_dataset_filename,start=0):
    print(test_index)
    y_test_predprob_regBase[test_index] = model_regBase.predict_proba(x_test[test_index])[:,1]
    print(y_test_predprob_regBase[test_index].shape)
    method_data[test_index] = np.append(method_data[test_index],y_test_predprob_regBase[test_index].reshape(-1,1),axis = 1)
# Out:
# 0
# (102,)

# %% [markdown]
# ### Stacking

# %%
y_test_predprob_stacking = {}
method_list.append('Stacking')
for test_index, test_file_name in enumerate(test_dataset_filename,start=0):
    print(test_index)
    y_test_predprob_stacking[test_index] = PAT_Stacking.predict_proba(x_test[test_index])[:,1]
    print(y_test_predprob_stacking[test_index].shape)
    method_data[test_index] = np.append(method_data[test_index],y_test_predprob_stacking[test_index].reshape(-1,1),axis = 1)
# Out:
# 0
# (102,)

# %%
from sklearn.metrics import roc_curve,roc_auc_score,auc,precision_recall_curve
from sklearn import metrics

def multi_method_AUROC(names,  colors, X_test, y_test,save_name,save=True, dpin=100):
        """
        Output the AUROC results obtained by all models to a graph
        
        Args:
            names: list, methods names
            sampling_methods: list, instantiated objects for all methods
            save: Choose whether to save the result (default is png format)
            
        Returns:
            Returns the image object plt
        """
        plt.figure(figsize=(5, 5), dpi=dpin)

        for (method_index, method_name) in enumerate(names, start=0):
            y_test_predprob = X_test[:,method_index]
            fpr, tpr, thresholds = roc_curve(y_test, y_test_predprob, pos_label=1)
            print(method_name)
            
            plt.plot(fpr, tpr, lw=2, label='{} (AUC={:.4f})'.format(method_name, auc(fpr, tpr)),color = colors[method_index])
            plt.plot([0, 1], [0, 1], '--', lw=5, color = 'grey')
            plt.axis('square')  
            plt.xlim([0, 1])
            plt.ylim([0, 1])
            plt.xlabel('False Positive Rate',fontsize=13)
            plt.ylabel('True Positive Rate',fontsize=13)
            #plt.title('ROC Curve',fontsize=8)
            plt.legend(loc='lower right',fontsize=8)

        if save:
            plt.savefig('PAT_multi_models_auroc'+save_name+'_otherMethod.png')
            
        return plt

# %%
from sklearn.metrics import roc_curve,roc_auc_score,auc,precision_recall_curve
from sklearn import metrics

def multi_method_AUPRC(names,  colors, X_test, y_test,save_name,save=True, dpin=100):
        """
        Output the AUPRC results obtained by all models to a graph
        
        Args:
            names: list, methods names
            sampling_methods: list, instantiated objects for all methods
            save: Choose whether to save the result (default is png format)
            
        Returns:
            Returns the image object plt
        """
        plt.figure(figsize=(5, 5), dpi=dpin)

        for (method_index, method_name) in enumerate(names, start=0):
            y_test_predprob = X_test[:,method_index]
            fpr, tpr, thresholds = roc_curve(y_test, y_test_predprob, pos_label=1)
            print(method_name)
            
            precision, recall,_ = precision_recall_curve(y_test, y_test_predprob)
            plt.plot(recall, precision, lw=2, label='{} (AUC={:.4f})'.format(method_name, auc(recall, precision)),color = colors[method_index])
            plt.plot([0, 1], [0, 1], '--', lw=5, color = 'grey')
            plt.axis('square')  
            plt.xlim([0, 1])
            plt.ylim([0, 1])
            plt.xlabel('False Positive Rate',fontsize=13)
            plt.ylabel('True Positive Rate',fontsize=13)
            #plt.title('AUPR Curve',fontsize=6)
            plt.legend(loc='lower right',fontsize=8)

        if save:
            plt.savefig('PAT_multi_models_aupr_'+save_name+'otherMethod.png')
            
        return plt

# %%
colors = ['crimson',
          'orange',
          'gold',
          'mediumseagreen',
          'steelblue', 
          'mediumpurple',
          'blue',
          'black'
]


multi_method_AUPRC(method_list, colors, method_data[0],y_test[0],save_name="Rare_Patho")
multi_method_AUROC(method_list, colors, method_data[0],y_test[0],save_name="Rare_Patho")
# Out:
# CADD
# CScape
# DANN
# FATHMM-MKL
# FIRE
# DeepGS
# regBase
# Stacking
# CADD
# CScape
# DANN
# FATHMM-MKL
# FIRE
# DeepGS
# regBase
# Stacking
# <module 'matplotlib.pyplot' from 'c:\\program files\\python36\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ### Save DeepGS & regBase

# %%
model_DeepGS.save('./model/PAT/PAT_DeepGS.h5')#这个方法将网络结构与权重一起保存到dnn.h5中
file_regBase = ".//model//PAT//" + "PAT_regBase" + ".model"

joblib.dump(model_regBase, filename = file_regBase)
# Out:
# ['.//model//PAT//PAT_regBase.model']
